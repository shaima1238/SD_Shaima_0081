# %% [markdown]
# <a href="https://colab.research.google.com/github/shaima1238/SD_Shaima_0081/blob/main/prac_bank__management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank_balance=1000
print("ATM MENU")
print("1.check balance")
print("2.withdraw Money")
option=int(input("enter your choice 1 or 2:"))
if option==1:
  print("your bank balance is:",bank_balance)
elif option==2:
    withdraw_amount=int(input("enter the amount to withdraw"))
if withdraw_amount<=bank_balance:
      bank_balance-=withdraw_amount
      print("withdraw successful")
      print("your current balance is:",bank_balance)
else:
  print("insufficient balance")
# Out:
# ATM MENU
# 1.check balance
# 2.withdraw Money
